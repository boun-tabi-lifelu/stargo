# %%
from pathlib import Path

base_dir = Path("go-basic-2020")
go_edition = base_dir / "go" # @param

# %%
# !git clone https://github.com/mmtftr/anc2vec.git
# Out:
# Cloning into 'anc2vec'...
# remote: Enumerating objects: 482, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 482 (delta 9), reused 20 (delta 8), pack-reused 454 (from 1)
# Receiving objects: 100% (482/482), 74.41 MiB | 2.33 MiB/s, done.
# Resolving deltas: 100% (235/235), done.

# %%
# %cd anc2vec
# Out:
# /Users/mmtf/p/research/contempro/work/go-embedding-eval/anc2vec

# %%
import wandb
from google.colab import userdata

wandb_key = userdata.get("WANDB_API_KEY")

import os
os.environ["WANDB_API_KEY"] = wandb_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 import wandb
# ----> 2 from google.colab import userdata
#       4 wandb_key = userdata.get("WANDB_API_KEY")
#       6 import os
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
go_file = go_edition.replace("-full","")
# !cp /content/drive/MyDrive/research/{go_edition}.sbert.ontology.embeddings.npy .
# !wget https://release.geneontology.org/2024-09-08/ontology/{go_file}.obo -O {go_edition}.obo
# Out:
# --2024-11-27 21:12:43--  https://release.geneontology.org/2024-09-08/ontology/go.obo
# Resolving release.geneontology.org (release.geneontology.org)... 104.18.42.207, 172.64.145.49, 2606:4700:4400::6812:2acf, ...
# Connecting to release.geneontology.org (release.geneontology.org)|104.18.42.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34785741 (33M) [text/obo]
# Saving to: ‘go-full.obo’
#
# go-full.obo         100%[===================>]  33.17M  29.8MB/s    in 1.1s
#
# 2024-11-27 21:12:44 (29.8 MB/s) - ‘go-full.obo’ saved [34785741/34785741]

# %%
# !mkdir -p ../go-basic-2020/sbert-anc2vec-2

# !python -m anc2vec.train.cli \
    --obo-file ../{base_dir}/go.obo \
    --embeddings-path ../{base_dir}/sbert/ontology.embeddings.npy \
    --output-path ../{base_dir}/sbert-anc2vec-2/ontology.embeddings.npy \
    --embedding-size 200 \
    --batch-size 32 \
    --epochs 100 \
    --ance-weight 1.0 \
    --name-weight 0.5 \
    --auto-weight 0.3 \
    --initial-lr 0.001 \
    --use-lr-schedule \
    --wandb-project "anc2vec" \
    --wandb-entity "mmtf"
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: mmtftr (mmtf). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.1
# wandb: Run data is saved locally in /Users/mmtf/p/research/contempro/work/go-embedding-eval/anc2vec/wandb/run-20241225_192111-ndhju27k
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run whole-dawn-16
# wandb: ⭐️ View project at https://wandb.ai/mmtf/anc2vec
# wandb: 🚀 View run at https://wandb.ai/mmtf/anc2vec/runs/ndhju27k
# WARNING:tensorflow:From /Users/mmtf/p/research/contempro/work/go-embedding-eval/anc2vec/anc2vec/train/dataset.py:87: calling DatasetV2.from_generator (from tensorflow.python.data.ops.dataset_ops) with output_types is deprecated and will be removed in a future version.
# Instructions for updating:
# Use output_signature instead
# ...

# %%
# !cp ./{go_edition}.sbert-anc2vec-2.ontology.embeddings.npy /content/drive/MyDrive/research

# %%
# !sleep 5 # wait for file to upload (copies are not instant)
# end session after
from google.colab import runtime
runtime.unassign()
